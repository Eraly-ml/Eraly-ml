# %%
print('its working?')
# Out:
# its working?

# %%
import numpy as np

# %%
e = np.array([[1, 2],
              [2, 4]])
s = np.array([[3],
              [3]])
print(e * s)
# Out:
# [[ 3  6]
#  [ 6 12]]
